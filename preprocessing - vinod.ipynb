# %% [markdown]
# # Preprocessing of the data from Vinod's MongoDB database

# %%
import pandas as pd
import numpy as np
from collections import Counter, defaultdict
import pickle
from tqdm import tqdm, tqdm_notebook

# %% [markdown]
# # Load the data

# %%
PATH2 = 'data/vinod/'
f_power_labels = f"{PATH2}Columbia_Enron_DominanceTuples.csv"
f_gender_labels = f"{PATH2}Columbia_Enron_FirstName_Gender_Type.csv"
f_vinod_corpus = f"{PATH2}cleaned_v1_mongo.pkl"

# %%
# Load the data
power_labels = pd.read_csv(f_power_labels)
gender_labels = pd.read_csv(f_gender_labels)

# Round-about loading, possibly because it was saved in python2
with open(f_vinod_corpus, 'rb') as f:
    data = pickle.load(f, encoding='latin1')

# %% [markdown]
# # Clean the data

# %%
# Clean the gender labels
gender_labels = gender_labels[gender_labels['FirstName'] != 'None']
gender_labels.reset_index(drop=True, inplace=True)

# Build dicts for easy dataset merging
gender_dict = defaultdict(lambda: 'I')
employee_dict = defaultdict(lambda: 'unk')
ambiguity_dict = defaultdict(lambda: 'NotFound')
for _, (uid, _, ambig, gender, employee_type) in gender_labels.iterrows():
    gender_dict[uid] = gender
    employee_dict[uid] = employee_type
    try:
        ambig = round(ambig, 3)
    except TypeError:
        pass
    ambiguity_dict[uid] = ambig

# %%
# Build a power dict for easy look-up
power_dict = defaultdict(lambda: 'na')

for _, (boss, sub, imd) in power_labels.iterrows():
    power_dict[(boss, sub)] = imd

# %%
# Clean out the main messages    
data.dropna(inplace=True)

# Drop ones which lack a from_id
msk = data['from_id'].apply(lambda v: type(v) is int)
data = data[msk]

# %% [markdown]
# # Merge the labels into one dataset

# %%
# Make big csv
# Make slimmed csv (main message, power labels, message type) with key to decode int labels

# %%
# Add from_id data
data.loc[:, 'from_gender'] = [gender_dict[uid] for uid in data['from_id']]
data.loc[:, 'from_ambig'] = [ambiguity_dict[uid] for uid in data['from_id']]
data.loc[:, 'from_employee_type'] = [employee_dict[uid] for uid in data['from_id']]

# Drop out unknown employee types
data = data[data['from_employee_type'] != 'unk']

# %%
# Add to_ids data
data.loc[:, 'to_gender'] = [[gender_dict[uid] for uid in row['to_ids']] for _, row in data.iterrows()]
data.loc[:, 'to_ambig'] = [[ambiguity_dict[uid] for uid in row['to_ids']] for _, row in data.iterrows()]
data.loc[:, 'to_employee_type'] = [[employee_dict[uid] for uid in row['to_ids']] for _, row in data.iterrows()]

# %%
# Add cc_ids data
data.loc[:, 'cc_gender'] = [[gender_dict[uid] for uid in row['cc']] for _, row in data.iterrows()]
data.loc[:, 'cc_ambig'] = [[ambiguity_dict[uid] for uid in row['cc']] for _, row in data.iterrows()]
data.loc[:, 'cc_employee_type'] = [[employee_dict[uid] for uid in row['cc']] for _, row in data.iterrows()]

# %%
# Add all power relations

# %%
def get_power_relations(from_id, to_ids):
    power_relation_exists = []
    power_relation_imd = []
    for i, to_id in enumerate(to_ids):
        tup, imd = get_power_relation(from_id, to_id)
        if tup != 'na':
            power_relation_exists.append(tup)
            power_relation_imd.append(imd)
    
    return power_relation_exists, power_relation_imd

def get_power_relation(from_id, to_id):
    tup = (from_id, to_id)
    power = power_dict[tup]
    if power == 'na':
        tup = (to_id, from_id)
        power = power_dict[tup]
        if power == 'na':
            tup = 'na'
    return tup, power

# %%
# Extract power relations for recipients
power_relations = []
power_imds = []

for i, row in tqdm_notebook(data.iterrows()):
    from_id = row['from_id']
    to_ids = row['to_ids']
    
    power, imds = get_power_relations(from_id, to_ids)
    power_relations.append(power)
    power_imds.append(imds)

data['to_power_rels'] = power_relations
data['to_power_imds'] = power_imds
# Out:
# A Jupyter Widget

# %%
# Extract power relations for cc'd ids
power_relations = []
power_imds = []

for i, row in tqdm_notebook(data.iterrows()):
    from_id = row['from_id']
    to_ids = row['cc']
    
    power, imds = get_power_relations(from_id, to_ids)
    power_relations.append(power)
    power_imds.append(imds)

data['cc_power_rels'] = power_relations
data['cc_power_imds'] = power_imds
# Out:
# A Jupyter Widget

# %% [markdown]
# # Save out merged data

# %%
f_out_large = f"{PATH2}full_data.pkl"
f_out_small = f"{PATH2}full_data_small.pkl"

f_out_power = f"{PATH2}power_relations_only.pkl"

# %%
with open(f_out_large, 'wb') as f:
    pickle.dump(data, f)

# %%
# Slightly smaller version of the data
data_small = data[['main_text', 'message_type', 'subject',
                   'from_id', 'to_ids', 'cc',
                   'from_gender', 'to_gender', 'cc_gender',
                   'from_employee_type', 'to_employee_type', 'cc_employee_type',
                   'to_power_rels', 'cc_power_rels',
                   'to_power_imds', 'cc_power_imds']]

with open(f_out_small, 'wb') as f:
    pickle.dump(data_small, f)

# %%
# Power relations only
msk1 = data['to_power_rels'].apply(lambda p: len(p) > 0)
msk2 = data['cc_power_rels'].apply(lambda p: len(p) > 0)
msk = msk1 | msk2
data_power_only = data[msk]

with open(f_out_power, 'wb') as f:
    pickle.dump(data_power_only, f)

# %%
data_power_only
# Out:
#                                                   all_text  \
# uid
# 204      [{'content': 'Welcome to UBS Warburg Energy, L...
# 228      [{'content': 'Preparations are continuing for ...
# 248      [{'content': 'We are continuing work to ensure...
# 277      [{'content': 'Email a Friend brought to you by...
# 299      [{'content': 'With the filing of the Hart-Scot...
# 314      [{'content': 'All:
# A more detailed version  of...
# 338      [{'content': 'To the West Desk et al:
#
# The FER...
# 2701     [{'content': 'I have a very important video an...
# 2744     [{'content': 'Date: Thursday, January 24, 2002...
# 2745     [{'content': 'UBS have organized an important ...
# 2754     [{'content': 'Many of you have asked whether y...
# 2761     [{'content': 'As many of you know, I have a pr...
# 2763     [{'content': 'Attached is a copy of a sample l...
# 2765     [{'content': 'Today, we announced plans to mer...
# 2766     [{'content': 'I have a very important video an...
# 2767     [{'content': 'Today we released additional inf...
# 2768     [{'content': 'Enron and Dynegy each announced ...
# 2770     [{'content': 'Today was a very difficult day f...
# 2771     [{'content': 'This has been a tough couple of ...
# 2774     [{'content': 'Today we announced another posit...
# 2777     [{'content': 'Here is an update on new develop...
# 2780     [{'content': 'Today we announced the appointme...
# 2781     [{'content': 'I want to remind you about our A...
# 2862     [{'content': 'Attached are the Termination Lis...
# 2898     [{'content': 'Just in case you didn't see this...
# 2900     [{'content': 'Please see attached.', 'splitter...
# 2913     [{'content': 'FYI, the California dockets are ...
# 2915     [{'content': 'Commenting on his general percep...
# 2918     [{'content': '"Spot" Traders:
#
# Sarah Novosel, ...
# 2923     [{'content': 'I have prepared a handout which ...
# ...                                                    ...
# 1361978  [{'content': 'Jay,
# I have to add another item ...
# 1361990  [{'content': 'To All:
#
# Please mark your calend...
# 1361994  [{'content': 'Dear Vince,
#
# I just sent this me...
# 1362008  [{'content': 'Hi Rich and Key,
# Again I think y...
# 1362011  [{'content': 'Hi All,
# The full requirement dis...
# 1362013  [{'content': 'Hi Krishnarao,
#
# Here is the ip a...
# 1362018  [{'content': 'Tanya,
# When do you think we will...
# 1362022  [{'content': 'Vince,
# just wanted to summarize ...
# 1362026  [{'content': 'Dear Zimin,
#
# Attached are a FEA ...
# 1362030  [{'content': 'Thank you for attending to the t...
# 1362031  [{'content': 'Paulo and Tom,
#
# I have created a...
# 1362032  [{'content': 'Dear Zimin,
#
# Please find attache...
# 1362043  [{'content': 'Bob,
#
# I finished the draft of  S...
# 1362047  [{'content': 'Hi all,
# We have updated the PSIM...
# 1362048  [{'content': 'Vince,
#
# Enron Japan received a p...
# 1362051  [{'content': 'Over the past year, I've been do...
# 1362063  [{'content': 'Hey.  I'm going to be in town ne...
# 1362065  [{'content': 'Folks,
# Here's some preliminary c...
# 1362071  [{'content': 'I want to move forward with sche...
# 1362079  [{'content': 'Hi Vince,
#
# I saw that you will b...
# 1362107  [{'content': 'Vince and Zimin,
# PSIM presentati...
# 1362132  [{'content': '<< File: Rel_VAR_lucid1_WJK.doc ...
# 1362142  [{'content': 'Vince,
# I was thinking that max (...
# 1362171  [{'content': 'Hello all,
#
# We're planning on en...
# 1367534  [{'content': 'Please note that the EnronOnline...
# 1367604  [{'content': 'The new version of the EnronOnli...
# 1367710  [{'content': 'Submitted to FERC on 7.31.00.  K...
# 1367731  [{'content': 'The following are Brokers and th...
# 1367759  [{'content': 'Legal has been assessing the ris...
# 1367835  [{'content': 'The purpose of this e-mail is to...
#
#                                                         cc from_id  \
# uid
# 204                                                     []   18656
# 228              [28701, 1939, 18989, 79985, 53860, 14758]    1786
# 248                                                     []   28701
# 277                                                     []     836
# 299      [32737, 2619, 12499, 55055, 18989, 27723, 1939...   28701
# 314                             [1999, 7319, 28265, 35923]     836
# 338                                                     []     836
# 2701                                                    []   40164
# 2744                                                    []   18590
# 2745                                                    []  111105
# 2754                                                    []   20805
# 2761                                                    []   40164
# 2763                                                    []   40164
# 2765                                                    []   40164
# 2766                                                    []   40164
# 2767                                                    []   40164
# 2768                                                    []   40164
# 2770                                                    []   20805
# 2771                                                    []   20805
# 2774                                                    []   20805
# 2777                                                    []   20805
# 2780                                                    []   20805
# 2781                                                    []   20805
# 2862                                                    []    1235
# 2898                                                    []     247
# 2900                                                    []     247
# 2913     [11290, 3364, 836, 1377, 12467, 20464, 27095, ...    2659
# 2915                                                    []    2659
# 2918                                                    []     836
# 2923                                                    []     836
# ...                                                    ...     ...
# 1361978                                                 []   63574
# 1361990                                                 []   63574
# 1361994                                                 []   63574
# 1362008                         [2437, 71768, 3788, 63574]   22022
# 1362011                              [2437, 63574, 104362]   22022
# 1362013                                                 []   91386
# 1362018                                                 []  111066
# 1362022                                                 []  111066
# 1362026                                                 []    1393
# 1362030                               [91386, 2796, 67858]   22022
# 1362031                                            [63574]   89761
# 1362032                                            [63574]    1393
# 1362043                                            [63574]    1393
# 1362047                                                 []    6471
# 1362048                                                 []   67858
# 1362051                                                 []    1393
# 1362063                                     [63574, 26895]    5946
# 1362065                                      [63574, 1393]  112733
# 1362071                                            [93753]   67858
# 1362079                                                 []   65712
# 1362107                                     [6471, 112733]    6471
# 1362132                                                 []  111066
# 1362142                                                 []  104362
# 1362171                                                 []   28655
# 1367534                               [5063, 28395, 14758]   28701
# 1367604                               [14758, 5063, 28395]   28701
# 1367710                                                 []   27095
# 1367731                 [22475, 111470, 2512, 18397, 7320]    2525
# 1367759                                             [7320]   22475
# 1367835                                        [742, 5140]  114589
#
#                       from_name  \
# uid
# 204        Christopher F Calger
# 228                  Bob Shults
# 248               David Forster
# 277                 Alan Comnes
# 299               David Forster
# 314                 Alan Comnes
# 338                 Alan Comnes
# 2701                    Ken Lay
# 2744                David Oxley
# 2745             Tammie Schoppe
# 2754                    Ken Lay
# 2761                    Ken Lay
# 2763                    Ken Lay
# 2765                    Ken Lay
# 2766                    Ken Lay
# 2767                    Ken Lay
# 2768                    Ken Lay
# 2770                    Ken Lay
# 2771                    Ken Lay
# 2774                    Ken Lay
# 2777                    Ken Lay
# 2780                    Ken Lay
# 2781                    Ken Lay
# 2862            Stephanie Panus
# 2898               Dave Perrino
# 2900               Dave Perrino
# 2913                Ray Alvarez
# 2915                Ray Alvarez
# 2918                Alan Comnes
# 2923                Alan Comnes
# ...                         ...
# 1361978        Vince J Kaminski
# 1361990        Vince J Kaminski
# 1361994        Vince J Kaminski
# 1362008      Chonawee Supatgiat
# 1362011      Chonawee Supatgiat
# 1362013  Pinnamaneni Krishnarao
# 1362018       Tanya Tamarchenko
# 1362022       Tanya Tamarchenko
# 1362026                Zimin Lu
# 1362030      Chonawee Supatgiat
# 1362031            Paulo Issler
# 1362032                Zimin Lu
# 1362043                Zimin Lu
# 1362047              Alex Huang
# 1362048           Sandeep Kohli
# 1362051                Zimin Lu
# 1362063            Anita Dupont
# 1362065         Tom Halliburton
# 1362071           Sandeep Kohli
# 1362079        Kenneth Parkhill
# 1362107              Alex Huang
# 1362132       Tanya Tamarchenko
# 1362142       Vasant Shanbhogue
# 1362171            David Dronet
# 1367534           David Forster
# 1367604           David Forster
# 1367710           Jeff Dasovich
# 1367731             Shari Stack
# 1367759         Christian Yoder
# 1367835             Tom Delaney
#
#                                                  main_text message_type  \
# uid
# 204      Welcome to UBS Warburg Energy, LLC\n\nAll UBS ...      INITIAL
# 228      Preparations are continuing for our simulation...      INITIAL
# 248      We are continuing work to ensure our new onlin...      INITIAL
# 277      Email a Friend brought to you by BayArea.com a...      INITIAL
# 299      With the filing of the Hart-Scott-Rodino appli...      INITIAL
# 314      All:\nA more detailed version  of CAISO's MD02...           RE
# 338      To the West Desk et al:\n\nThe FERC's west-wid...      INITIAL
# 2701     I have a very important video announcement abo...      INITIAL
# 2744     Date: Thursday, January 24, 2002\n\nLocation: ...      INITIAL
# 2745     UBS have organized an important meeting  will ...      INITIAL
# 2754     Many of you have asked whether you should come...      INITIAL
# 2761     As many of you know, I have a provision in my ...      INITIAL
# 2763     Attached is a copy of a sample letter which we...      INITIAL
# 2765     Today, we announced plans to merge with Dynegy...      INITIAL
# 2766     I have a very important video announcement abo...      INITIAL
# 2767     Today we released additional information about...      INITIAL
# 2768     Enron and Dynegy each announced today that the...      INITIAL
# 2770     Today was a very difficult day for us as marke...      INITIAL
# 2771     This has been a tough couple of weeks.  I hope...      INITIAL
# 2774     Today we announced another positive developmen...      INITIAL
# 2777     Here is an update on new developments that hav...      INITIAL
# 2780     Today we announced the appointment of Jeff McM...      INITIAL
# 2781     I want to remind you about our All-Employee Me...      INITIAL
# 2862     Attached are the Termination Lists for January...      INITIAL
# 2898     Just in case you didn't see this,\nPacific NW ...      INITIAL
# 2900                                  Please see attached.           FW
# 2913     FYI, the California dockets are on the agenda ...      INITIAL
# 2915     Commenting on his general perception of the se...      INITIAL
# 2918     "Spot" Traders:\n\nSarah Novosel, Ray Alvarez ...           RE
# 2923     I have prepared a handout which I will make av...           RE
# ...                                                    ...          ...
# 1361978  Jay,\nI have to add another item to a long lis...           FW
# 1361990  To All:\n\nPlease mark your calendars for 26 S...           RE
# 1361994  Dear Vince,\n\nI just sent this message to you...           FW
# 1362008  Hi Rich and Key,\nAgain I think your idea is v...           RE
# 1362011  Hi All,\nThe full requirement dispatch applica...           FW
# 1362013  Hi Krishnarao,\n\nHere is the ip address link ...           FW
# 1362018  Tanya,\nWhen do you think we will be able to i...           FW
# 1362022  Vince,\njust wanted to summarize for you how I...
# 1362026  Dear Zimin,\n\nAttached are a FEA Add-In Price...           FW
# 1362030  Thank you for attending to the talk last Frida...      INITIAL
# 1362031  Paulo and Tom,\n\nI have created a directory S...           RE
# 1362032  Dear Zimin,\n\nPlease find attached a document...           FW
# 1362043  Bob,\n\nI finished the draft of  Summary to be...      INITIAL
# 1362047  Hi all,\nWe have updated the PSIM model. The c...      INITIAL
# 1362048  Vince,\n\nEnron Japan received a presentation ...           RE
# 1362051  Over the past year, I've been doing a lot of w...           RE
# 1362063  Hey.  I'm going to be in town next week, and w...           RE
# 1362065  Folks,\nHere's some preliminary comments on th...      INITIAL
# 1362071  I want to move forward with scheduling the ini...           FW
# 1362079  Hi Vince,\n\nI saw that you will be featured o...      INITIAL
# 1362107  Vince and Zimin,\nPSIM presentation is schedul...      INITIAL
# 1362132                 << File: Rel_VAR_lucid1_WJK.doc >>           RE
# 1362142  Vince,\nI was thinking that max (negative)  po...      INITIAL
# 1362171  Hello all,\n\nWe're planning on enjoying this ...      INITIAL
# 1367534  Please note that the EnronOnline Phase 2 train...      INITIAL
# 1367604  The new version of the EnronOnline website is ...      INITIAL
# 1367710  Submitted to FERC on 7.31.00.  Key findings:\n...      INITIAL
# 1367731  The following are Brokers and their respective...      INITIAL
# 1367759  Legal has been assessing the risks of doing bl...      INITIAL
# 1367835  The purpose of this e-mail is to update the re...      INITIAL
#
#                                                    subject  \
# uid
# 204                       UBSW ENERGY KICK-OFF CELEBRATION
# 228                      Online Trading Simulation Feb 7th
# 248                              Online Trading Simulation
# 277            CAISO Responds to McCullough's inane claims
# 299                              Online Launch Plan Update
# 314            California ISO Market Re-Design 2002 (MD02)
# 338      Details on the West-wide Price cap: now $108/M...
# 2701                          IMPORTANT VIDEO ANNOUNCEMENT
# 2744     URGENT - REQUIRES IMMEDIATE ACTION - UBS Orien...
# 2745     URGENT REQUIRES IMMEDIATE ACTION : Welcome to ...
# 2754                  UPDATE - Reporting to Work Next Week
# 2761                          Change of Control Provisions
# 2763        Conflict of Interest Policy Mailing to Vendors
# 2765            Enron Announces Plans to Merge with Dynegy
# 2766                          IMPORTANT VIDEO ANNOUNCEMENT
# 2767                  SEC Information/Earnings Restatement
# 2768                                    Dynegy Discussions
# 2770                                          Daily Update
# 2771                                          Enron Update
# 2774                                          Daily Update
# 2777                                          Daily Update
# 2780                                Jeff McMahon Named CFO
# 2781                                  All-Employee Meeting
# 2862                                       Termination Log
# 2898     Pacific NW Lawmakers Gear Up To Oppose FERC RT...
# 2900     EL01-89 Morgan Stanley Capital Group Inc. v. C...
# 2913                     FERC & BPA Weekly Electric Report
# 2915     Summary- Judge's Recommendation re Retroactive...
# 2918                    Questions re: FERC June 19th Order
# 2923     Informational Brown-Bag, Tuesday, June 26th - ...
# ...                                                    ...
# 1361978                                    EOL Data Mining
# 1361990                                 Need to move quick
# 1361994                           Collaboration with Enron
# 1362008                         calculating bid-ask prices
# 1362011
# 1362013                                    link to program
# 1362018
# 1362022
# 1362026                                FEA @ENERGY/Storage
# 1362030  Installation for Full Requirement Dispatch App...
# 1362031                                      Storage model
# 1362032                                    @ENERGY/Storage
# 1362043               Executive Summary of EOL Data Mining
# 1362047                                      PSIM progress
# 1362048  Boltzmann Model Demonstration from Toshiba in ...
# 1362051                                Bid-offer Algorithm
# 1362063                                            Houston
# 1362065                               ModReg for Argentina
# 1362071                        Operational Risk Management
# 1362079                       leadership conference at MIT
# 1362107                Invitees for Tuesday's presentation
# 1362132                                              Paper
# 1362142                                         Cash needs
# 1362171                                             drinks
# 1367534                  EnronOnline Training Dates Change
# 1367604                                EnronOnline Phase 2
# 1367710  CalPX Market Compliance Unit Submits its 2nd A...
# 1367731                        CAISO Energy - Brokers  (2)
# 1367759                     Block Forward Financial Trades
# 1367835  Update on Discussions between CAISO and DSW Pa...
#
#                                                     to_ids  \
# uid
# 204      [567, 52125, 111470, 117105, 18656, 3786, 5348...
# 228                                  [32825, 32827, 14326]
# 248      [19927, 111470, 18656, 53481, 26954, 1621, 267...
# 277      [2236, 19927, 7790, 2659, 2512, 111470, 26887,...
# 299                    [32825, 32823, 32827, 32826, 14326]
# 314      [836, 111470, 2512, 3493, 20403, 18397, 4758, ...
# 338      [35923, 111470, 270, 7319, 1999, 35901, 106180...
# 2701                                         [32790, 2983]
# 2744     [14131, 111015, 19927, 52125, 8784, 36121, 251...
# 2745     [14131, 111015, 19927, 52125, 8784, 36121, 251...
# 2754                                          [7437, 2983]
# 2761                                         [32775, 2983]
# 2763                                         [32772, 2983]
# 2765                                         [32775, 2983]
# 2766                                         [32775, 2983]
# 2767                                         [32783, 2983]
# 2768                                         [32783, 2983]
# 2770                                          [3857, 2983]
# 2771                                          [3857, 2983]
# 2774                                          [3857, 2983]
# 2777                                          [3857, 2983]
# 2780                                          [3857, 2983]
# 2781                                          [3857, 2983]
# 2862     [2097, 19927, 3611, 2414, 36162, 111470, 10226...
# 2898               [11290, 836, 1917, 19927, 26954, 32017]
# 2900         [836, 3364, 11290, 26954, 32017, 2659, 36178]
# 2913     [111470, 49232, 2671, 29545, 2512, 32017, 2695...
# 2915     [7320, 732, 98057, 18327, 2482, 35901, 27095, ...
# 2918     [836, 26954, 111470, 3493, 1917, 19927, 32017,...
# 2923     [73909, 32836, 2659, 35901, 3364, 27095, 247, ...
# ...                                                    ...
# 1361978                                             [3082]
# 1361990                                             [1206]
# 1361994                                             [1206]
# 1362008                                [554, 36326, 63574]
# 1362011                 [6471, 112733, 1393, 67858, 63574]
# 1362013                                            [63574]
# 1362018                                            [63574]
# 1362022                                            [63574]
# 1362026                                            [63574]
# 1362030  [6471, 71768, 26142, 63574, 1393, 104362, 1127...
# 1362031                              [1393, 112733, 63574]
# 1362032                                    [112733, 63574]
# 1362043                                      [3082, 63574]
# 1362047                               [63574, 1393, 67858]
# 1362048                                     [75926, 63574]
# 1362051                                            [63574]
# 1362063                                      [1136, 63574]
# 1362065                   [24511, 1231, 3802, 3057, 63574]
# 1362071                              [63574, 25496, 26895]
# 1362079                                            [63574]
# 1362107                                      [63574, 1393]
# 1362132                                            [63574]
# 1362142                                            [63574]
# 1362171  [7888, 24435, 18735, 4769, 14124, 959, 111265,...
# 1367534  [5541, 3796, 3420, 6428, 3679, 17423, 541, 275...
# 1367604                                      [38585, 2512]
# 1367710  [7320, 742, 83264, 101554, 28380, 111470, 2512...
# 1367731                    [1526, 8249, 1678, 35769, 2512]
# 1367759     [111470, 2512, 18397, 201, 19027, 83280, 3680]
# 1367835                        [19927, 111470, 2512, 4306]
#
#                                                   to_names from_gender  \
# uid
# 204      [Susan Amador, John Anderson, Tim Belden, Vict...           M
# 228      [DL-NETCO Gas Traders, DL-NETCO Power Traders,...           M
# 248      [Tom Alonso, Tim Belden, Christopher F Calger,...           M
# 277      [Jim Buerkle, Tom Alonso, Alvarez, Ray, Robert...           M
# 299      [DL-NETCO Gas Traders, DL-NETCO Gas Originator...           M
# 314      [Alan Comnes, Tim Belden, Robert Badeer, Chris...           M
# 338      [Sarah Novosel, Tim Belden, Richard Shapiro, J...           M
# 2701                     [DL-GA-all_ews, Cdean2@ENRON.com]           M
# 2744     [Bill Abler, Thresa A Allen, Tom Alonso, John ...           M
# 2745     [Bill Abler, Thresa A Allen, Tom Alonso, John ...           F
# 2754     [All Enron Employees United States Group, Cdea...           M
# 2761        [DL-GA-all_enron_worldwide1, Cdean2@ENRON.com]           M
# 2763     [DL-GA-all_enron_north_america1, Cdean2@ENRON....           M
# 2765        [DL-GA-all_enron_worldwide1, Cdean2@ENRON.com]           M
# 2766        [DL-GA-all_enron_worldwide1, Cdean2@ENRON.com]           M
# 2767         [DL-GA-all_enron_worldwide, Cdean2@ENRON.com]           M
# 2768         [DL-GA-all_enron_worldwide, Cdean2@ENRON.com]           M
# 2770               [All Enron Worldwide, Cdean2@ENRON.com]           M
# 2771               [All Enron Worldwide, Cdean2@ENRON.com]           M
# 2774               [All Enron Worldwide, Cdean2@ENRON.com]           M
# 2777               [All Enron Worldwide, Cdean2@ENRON.com]           M
# 2780               [All Enron Worldwide, Cdean2@ENRON.com]           M
# 2781               [All Enron Worldwide, Cdean2@ENRON.com]           M
# 2862     [Laurel Adams, Tom Alonso, Alan Aronowitz, Sus...           F
# 2898     [Steve Walton, Alan Comnes, Mark Fischer, Tom ...           M
# 2900     [Alan Comnes, Susan Mara, Steve Walton, Sean C...           M
# 2913     [Tim Belden, Mike Swerzbin, Michael M Driscoll...           M
# 2915     [James Steffes, Jeffrey T Hodge, Robert C Will...           M
# 2918     [Alan Comnes, Sean Crandall, Tim Belden, Chris...           M
# 2923     [Lysa Tracy, DL-Portland World Trade Center, R...           M
# ...                                                    ...         ...
# 1361978                                          [Bob Lee]           M
# 1361990                                   [Mike A Roberts]           M
# 1361994                                   [Mike A Roberts]           M
# 1362008  [Richard DiMichele, Key Kasravi, Kaminski@ENRO...           I
# 1362011  [Alex Huang, Tom Halliburton, Zimin Lu, Sandee...           I
# 1362013                               [Kaminski@ENRON.com]           F
# 1362018                               [Kaminski@ENRON.com]           F
# 1362022                               [Kaminski@ENRON.com]           F
# 1362026                               [Kaminski@ENRON.com]           I
# 1362030  [Alex Huang, Martin Lin, Lance Cunningham, Kam...           I
# 1362031    [Zimin Lu, Tom Halliburton, Kaminski@ENRON.com]           M
# 1362032              [Tom Halliburton, Kaminski@ENRON.com]           I
# 1362043                      [Bob Lee, Kaminski@ENRON.com]           I
# 1362047      [Kaminski@ENRON.com, Zimin Lu, Sandeep Kohli]           M
# 1362048                   [Mark Brady, Kaminski@ENRON.com]           M
# 1362051                               [Kaminski@ENRON.com]           I
# 1362063        [Kevin_Kindall@fpl.com, Kaminski@ENRON.com]           F
# 1362065  [Remi Collonges, David M Rosenberg, Jorge Gumu...           M
# 1362071  [Kaminski@ENRON.com, Shirley Crenshaw, Shirley...           M
# 1362079                               [Kaminski@ENRON.com]           M
# 1362107                     [Kaminski@ENRON.com, Zimin Lu]           M
# 1362132                               [Kaminski@ENRON.com]           F
# 1362142                               [Kaminski@ENRON.com]           I
# 1362171  [Amanda Rybarski, Colin Tonks, Chuck Ames, Vla...           M
# 1367534  [Andrew R Conner, Allan Ford, Adam Gross, Brad...           M
# 1367604        [EOL Traders World Wide, rbadeer@enron.com]           M
# 1367710  [James D Steffes, Paul Kaufman, Mona L Petroch...           M
# 1367731  [Evelyn Metoyer, Amy Degeyter, Stephanie Piwet...           F
# 1367759  [Tim Belden, rbadeer@enron.com, Jeff Richter, ...           M
# 1367835  [Tom Alonso, Tim Belden, rbadeer@enron.com, Ma...           M
#
#              ...                                               to_gender  \
# uid          ...
# 204          ...       [F, M, M, M, M, F, F, M, F, F, M, F, M, M, F, ...
# 228          ...                                               [I, I, M]
# 248          ...       [M, M, M, F, M, F, M, M, M, M, F, M, M, M, M, ...
# 277          ...       [M, M, M, M, M, M, M, M, M, M, M, M, M, I, F, ...
# 299          ...                                         [I, I, I, I, M]
# 314          ...                 [M, M, M, M, M, M, M, M, M, M, M, M, M]
# 338          ...       [F, M, M, F, F, F, F, M, M, M, M, M, M, M, M, ...
# 2701         ...                                                  [I, M]
# 2744         ...       [M, F, M, M, M, F, M, M, F, F, M, M, F, M, M, ...
# 2745         ...       [M, F, M, M, M, F, M, M, F, F, M, M, F, M, M, ...
# 2754         ...                                                  [I, M]
# 2761         ...                                                  [I, M]
# 2763         ...                                                  [I, M]
# 2765         ...                                                  [I, M]
# 2766         ...                                                  [I, M]
# 2767         ...                                                  [I, M]
# 2768         ...                                                  [I, M]
# 2770         ...                                                  [I, M]
# 2771         ...                                                  [I, M]
# 2774         ...                                                  [I, M]
# 2777         ...                                                  [I, M]
# 2780         ...                                                  [I, M]
# 2781         ...                                                  [I, M]
# 2862         ...       [F, M, M, F, M, M, F, F, M, M, F, M, M, F, F, ...
# 2898         ...                                      [M, M, M, M, M, F]
# 2900         ...                                   [M, F, M, M, F, M, M]
# 2913         ...       [M, M, M, M, M, F, M, M, M, M, M, M, F, M, M, ...
# 2915         ...       [F, M, M, F, M, F, M, M, F, M, F, F, F, F, M, ...
# 2918         ...           [M, M, M, M, M, M, F, M, M, M, M, M, F, F, F]
# 2923         ...                                [F, I, M, F, F, M, M, F]
# ...          ...                                                     ...
# 1361978      ...                                                     [M]
# 1361990      ...                                                     [M]
# 1361994      ...                                                     [M]
# 1362008      ...                                               [M, M, M]
# 1362011      ...                                         [M, M, I, M, M]
# 1362013      ...                                                     [M]
# 1362018      ...                                                     [M]
# 1362022      ...                                                     [M]
# 1362026      ...                                                     [M]
# 1362030      ...        [M, M, M, M, I, I, M, I, I, I, M, M, M, M, M, F]
# 1362031      ...                                               [I, M, M]
# 1362032      ...                                                  [M, M]
# 1362043      ...                                                  [M, M]
# 1362047      ...                                               [M, I, M]
# 1362048      ...                                                  [M, M]
# 1362051      ...                                                     [M]
# 1362063      ...                                                  [M, M]
# 1362065      ...                                         [M, M, M, M, M]
# 1362071      ...                                               [M, F, F]
# 1362079      ...                                                     [M]
# 1362107      ...                                                  [M, I]
# 1362132      ...                                                     [M]
# 1362142      ...                                                     [M]
# 1362171      ...       [F, M, M, M, I, M, F, M, M, M, M, M, M, F, F, ...
# 1367534      ...       [M, M, M, M, F, M, M, M, M, M, M, M, M, M, M, ...
# 1367604      ...                                                  [I, M]
# 1367710      ...       [F, F, F, F, M, M, M, M, M, I, M, F, F, F, M, ...
# 1367731      ...                                         [F, F, F, F, M]
# 1367759      ...                                   [M, M, M, F, F, M, M]
# 1367835      ...                                            [M, M, M, F]
#
#                                                   to_ambig  \
# uid
# 204      [0.439794775, 0.728227303, 0.48073235, 1.21449...
# 228                                [NotFound, NotFound, 0]
# 248      [0.62200817, 0.48073235, 1.013790345, 0.465748...
# 277      [0.684509435, 0.62200817, 0, 3.143279769, 0, 0...
# 299            [NotFound, NotFound, NotFound, NotFound, 0]
# 314      [0.497289084, 0.48073235, 0, 31.83223711, 31.8...
# 338      [0.763758064, 0.48073235, 0, 0.668081184, 0.30...
# 2701                                         [NotFound, 0]
# 2744     [0.590228982, 0, 0.62200817, 0.728227303, 0, 0...
# 2745     [0.590228982, 0, 0.62200817, 0.728227303, 0, 0...
# 2754                                         [NotFound, 0]
# 2761                                         [NotFound, 0]
# 2763                                         [NotFound, 0]
# 2765                                         [NotFound, 0]
# 2766                                         [NotFound, 0]
# 2767                                         [NotFound, 0]
# 2768                                         [NotFound, 0]
# 2770                                         [NotFound, 0]
# 2771                                         [NotFound, 0]
# 2774                                         [NotFound, 0]
# 2777                                         [NotFound, 0]
# 2780                                         [NotFound, 0]
# 2781                                         [NotFound, 0]
# 2862     [6.652711703, 0.62200817, 0.497289084, 0, 0.09...
# 2898       [0.672243959, 0.497289084, 0, 0.62200817, 0, 0]
# 2900     [0.497289084, 0.439794775, 0.672243959, 0, 0, ...
# 2913     [0.48073235, 0, 0.652273932, 0, 0, 0, 0, 31.83...
# 2915     [0, 0, 0.599400599, 0, 0, 0.502233144, 0, 0.67...
# 2918     [0.497289084, 0, 0.48073235, 31.83223711, 0, 0...
# 2923     [0, NotFound, 3.143279769, 0.502233144, 0.4397...
# ...                                                    ...
# 1361978                                      [0.599400599]
# 1361990                                      [0.652273932]
# 1361994                                      [0.652273932]
# 1362008                               [0.642741043, 25, 0]
# 1362011  [2.2161168, 0.62200817, NotFound, 5.291005291, 0]
# 1362013                                                [0]
# 1362018                                                [0]
# 1362022                                                [0]
# 1362026                                                [0]
# 1362030  [2.2161168, 0, 0.65743487, 0, NotFound, NotFou...
# 1362031                          [NotFound, 0.62200817, 0]
# 1362032                                    [0.62200817, 0]
# 1362043                                   [0.599400599, 0]
# 1362047                         [0, NotFound, 5.291005291]
# 1362048                                   [0.559861654, 0]
# 1362051                                                [0]
# 1362063                                   [0.957393257, 0]
# 1362065  [64.13994169, 0.628882614, 1.394845138, 64.139...
# 1362071                      [0, 1.872917763, 1.872917763]
# 1362079                                                [0]
# 1362107                                      [0, NotFound]
# 1362132                                                [0]
# 1362142                                                [0]
# 1362171  [0.622442278, 1.049361408, 0.060890215, 0, Not...
# 1367534  [0.866211996, 0.512754362, 0.856290274, 0, 0, ...
# 1367604                                      [NotFound, 0]
# 1367710  [0, 0.403819064, 0.189793982, 0, 0.333428211, ...
# 1367731  [0.86743035, 0.520900338, 0.624341947, 32.3355...
# 1367759  [0.48073235, 0, 0.418750947, 0, 0.484174982, 2...
# 1367835                     [0.62200817, 0.48073235, 0, 0]
#
#                                           to_employee_type  \
# uid
# 204      [NonCore, NonCore, NonCore, NonCore, NonCore, ...
# 228                               [NonCore, NonCore, Core]
# 248      [NonCore, NonCore, NonCore, NonCore, Core, Non...
# 277      [NonCore, NonCore, NonCore, NonCore, Core, Non...
# 299             [NonCore, NonCore, NonCore, NonCore, Core]
# 314      [NonCore, NonCore, Core, NonCore, NonCore, Non...
# 338      [NonCore, NonCore, Core, NonCore, NonCore, Non...
# 2701                                       [NonCore, Core]
# 2744     [NonCore, NonCore, NonCore, NonCore, NonCore, ...
# 2745     [NonCore, NonCore, NonCore, NonCore, NonCore, ...
# 2754                                       [NonCore, Core]
# 2761                                       [NonCore, Core]
# 2763                                       [NonCore, Core]
# 2765                                       [NonCore, Core]
# 2766                                       [NonCore, Core]
# 2767                                       [NonCore, Core]
# 2768                                       [NonCore, Core]
# 2770                                       [NonCore, Core]
# 2771                                       [NonCore, Core]
# 2774                                       [NonCore, Core]
# 2777                                       [NonCore, Core]
# 2780                                       [NonCore, Core]
# 2781                                       [NonCore, Core]
# 2862     [NonCore, NonCore, NonCore, Core, NonCore, Non...
# 2898         [NonCore, NonCore, Core, NonCore, Core, Core]
# 2900     [NonCore, NonCore, NonCore, Core, Core, NonCor...
# 2913     [NonCore, Core, NonCore, Core, Core, Core, Cor...
# 2915     [NonCore, Core, NonCore, Core, Core, NonCore, ...
# 2918     [NonCore, Core, NonCore, NonCore, Core, NonCor...
# 2923     [NonCore, NonCore, NonCore, NonCore, NonCore, ...
# ...                                                    ...
# 1361978                                          [NonCore]
# 1361990                                          [NonCore]
# 1361994                                          [NonCore]
# 1362008                           [NonCore, NonCore, Core]
# 1362011         [NonCore, NonCore, NonCore, NonCore, Core]
# 1362013                                             [Core]
# 1362018                                             [Core]
# 1362022                                             [Core]
# 1362026                                             [Core]
# 1362030  [NonCore, Core, NonCore, Core, NonCore, NonCor...
# 1362031                           [NonCore, NonCore, Core]
# 1362032                                    [NonCore, Core]
# 1362043                                    [NonCore, Core]
# 1362047                           [Core, NonCore, NonCore]
# 1362048                                    [NonCore, Core]
# 1362051                                             [Core]
# 1362063                                    [NonCore, Core]
# 1362065         [NonCore, NonCore, NonCore, NonCore, Core]
# 1362071                           [Core, NonCore, NonCore]
# 1362079                                             [Core]
# 1362107                                    [Core, NonCore]
# 1362132                                             [Core]
# 1362142                                             [Core]
# 1362171  [NonCore, NonCore, NonCore, Core, NonCore, Non...
# 1367534  [NonCore, NonCore, NonCore, Core, Core, NonCor...
# 1367604                                    [NonCore, Core]
# 1367710  [NonCore, NonCore, NonCore, NonCore, NonCore, ...
# 1367731         [NonCore, NonCore, NonCore, NonCore, Core]
# 1367759  [NonCore, Core, NonCore, NonCore, NonCore, Non...
# 1367835                     [NonCore, NonCore, Core, Core]
#
#                                              cc_gender  \
# uid
# 204                                                 []
# 228                                 [M, I, M, M, F, M]
# 248                                                 []
# 277                                                 []
# 299                        [I, F, F, F, M, M, I, M, M]
# 314                                       [F, F, M, F]
# 338                                                 []
# 2701                                                []
# 2744                                                []
# 2745                                                []
# 2754                                                []
# 2761                                                []
# 2763                                                []
# 2765                                                []
# 2766                                                []
# 2767                                                []
# 2768                                                []
# 2770                                                []
# 2771                                                []
# 2774                                                []
# 2777                                                []
# 2780                                                []
# 2781                                                []
# 2862                                                []
# 2898                                                []
# 2900                                                []
# 2913     [M, F, M, F, F, F, M, F, F, M, F, F, F, F, F]
# 2915                                                []
# 2918                                                []
# 2923                                                []
# ...                                                ...
# 1361978                                             []
# 1361990                                             []
# 1361994                                             []
# 1362008                                   [M, M, M, M]
# 1362011                                      [M, M, I]
# 1362013                                             []
# 1362018                                             []
# 1362022                                             []
# 1362026                                             []
# 1362030                                      [F, M, M]
# 1362031                                            [M]
# 1362032                                            [M]
# 1362043                                            [M]
# 1362047                                             []
# 1362048                                             []
# 1362051                                             []
# 1362063                                         [M, F]
# 1362065                                         [M, I]
# 1362071                                            [M]
# 1362079                                             []
# 1362107                                         [M, M]
# 1362132                                             []
# 1362142                                             []
# 1362171                                             []
# 1367534                                      [M, M, M]
# 1367604                                      [M, M, M]
# 1367710                                             []
# 1367731                                [M, M, M, M, F]
# 1367759                                            [F]
# 1367835                                         [F, M]
#
#                                                   cc_ambig  \
# uid
# 204                                                     []
# 228      [0.628882614, NotFound, 1.137012322, 0.8983240...
# 248                                                     []
# 277                                                     []
# 299      [NotFound, 0.755910493, 0.545606058, 0.5939341...
# 314      [0.304224573, 0.668081184, 0.418750947, 0.7637...
# 338                                                     []
# 2701                                                    []
# 2744                                                    []
# 2745                                                    []
# 2754                                                    []
# 2761                                                    []
# 2763                                                    []
# 2765                                                    []
# 2766                                                    []
# 2767                                                    []
# 2768                                                    []
# 2770                                                    []
# 2771                                                    []
# 2774                                                    []
# 2777                                                    []
# 2780                                                    []
# 2781                                                    []
# 2862                                                    []
# 2898                                                    []
# 2900                                                    []
# 2913     [0.672243959, 0.439794775, 0.497289084, 64.719...
# 2915                                                    []
# 2918                                                    []
# 2923                                                    []
# ...                                                    ...
# 1361978                                                 []
# 1361990                                                 []
# 1361994                                                 []
# 1362008                             [0, 0, 0.684509435, 0]
# 1362011                                   [0, 0, NotFound]
# 1362013                                                 []
# 1362018                                                 []
# 1362022                                                 []
# 1362026                                                 []
# 1362030            [58.97435897, 1.087584783, 5.291005291]
# 1362031                                                [0]
# 1362032                                                [0]
# 1362043                                                [0]
# 1362047                                                 []
# 1362048                                                 []
# 1362051                                                 []
# 1362063                                   [0, 1.872917763]
# 1362065                                      [0, NotFound]
# 1362071                                                [0]
# 1362079                                                 []
# 1362107                            [2.2161168, 0.62200817]
# 1362132                                                 []
# 1362142                                                 []
# 1362171                                                 []
# 1367534                                [0, 0.333428211, 0]
# 1367604                                [0, 0, 0.333428211]
# 1367710                                                 []
# 1367731       [12.75495841, 0.48073235, 0, 0.418750947, 0]
# 1367759                                                [0]
# 1367835                         [0.403819064, 0.418750947]
#
#                                           cc_employee_type  \
# uid
# 204                                                     []
# 228      [NonCore, NonCore, NonCore, NonCore, NonCore, ...
# 248                                                     []
# 277                                                     []
# 299      [NonCore, NonCore, NonCore, NonCore, NonCore, ...
# 314                   [NonCore, NonCore, NonCore, NonCore]
# 338                                                     []
# 2701                                                    []
# 2744                                                    []
# 2745                                                    []
# 2754                                                    []
# 2761                                                    []
# 2763                                                    []
# 2765                                                    []
# 2766                                                    []
# 2767                                                    []
# 2768                                                    []
# 2770                                                    []
# 2771                                                    []
# 2774                                                    []
# 2777                                                    []
# 2780                                                    []
# 2781                                                    []
# 2862                                                    []
# 2898                                                    []
# 2900                                                    []
# 2913     [NonCore, NonCore, NonCore, NonCore, NonCore, ...
# 2915                                                    []
# 2918                                                    []
# 2923                                                    []
# ...                                                    ...
# 1361978                                                 []
# 1361990                                                 []
# 1361994                                                 []
# 1362008                     [NonCore, Core, NonCore, Core]
# 1362011                           [NonCore, Core, NonCore]
# 1362013                                                 []
# 1362018                                                 []
# 1362022                                                 []
# 1362026                                                 []
# 1362030                        [NonCore, NonCore, NonCore]
# 1362031                                             [Core]
# 1362032                                             [Core]
# 1362043                                             [Core]
# 1362047                                                 []
# 1362048                                                 []
# 1362051                                                 []
# 1362063                                    [Core, NonCore]
# 1362065                                    [Core, NonCore]
# 1362071                                          [NonCore]
# 1362079                                                 []
# 1362107                                 [NonCore, NonCore]
# 1362132                                                 []
# 1362142                                                 []
# 1362171                                                 []
# 1367534                              [Core, NonCore, Core]
# 1367604                              [Core, Core, NonCore]
# 1367710                                                 []
# 1367731         [NonCore, NonCore, Core, NonCore, NonCore]
# 1367759                                          [NonCore]
# 1367835                                 [NonCore, NonCore]
#
#                                              to_power_rels  \
# uid
# 204                                        [(18656, 2149)]
# 228                                                     []
# 248      [(2273, 28701), (28701, 2619), (28701, 18989),...
# 277                                         [(11290, 836)]
# 299                                                     []
# 314                                                     []
# 338      [(270, 836), (7319, 836), (1999, 836), (35901,...
# 2701                                       [(40164, 2983)]
# 2744                       [(2273, 18590), (27104, 18590)]
# 2745                     [(2273, 111105), (27104, 111105)]
# 2754                                       [(20805, 2983)]
# 2761                                       [(40164, 2983)]
# 2763                                       [(40164, 2983)]
# 2765                                       [(40164, 2983)]
# 2766                                       [(40164, 2983)]
# 2767                                       [(40164, 2983)]
# 2768                                       [(40164, 2983)]
# 2770                                       [(20805, 2983)]
# 2771                                       [(20805, 2983)]
# 2774                                       [(20805, 2983)]
# 2777                                       [(20805, 2983)]
# 2780                                       [(20805, 2983)]
# 2781                                       [(20805, 2983)]
# 2862                                        [(2378, 1235)]
# 2898                                        [(11290, 247)]
# 2900                                        [(11290, 247)]
# 2913                                                    []
# 2915          [(18327, 2659), (35901, 2659), (1999, 2659)]
# 2918                                         [(1999, 836)]
# 2923                                        [(35901, 836)]
# ...                                                    ...
# 1361978                                    [(63574, 3082)]
# 1361990                                    [(63574, 1206)]
# 1361994                                    [(63574, 1206)]
# 1362008                                   [(63574, 22022)]
# 1362011                   [(67858, 22022), (63574, 22022)]
# 1362013                                   [(63574, 91386)]
# 1362018                                  [(63574, 111066)]
# 1362022                                  [(63574, 111066)]
# 1362026                                    [(63574, 1393)]
# 1362030                                   [(63574, 22022)]
# 1362031                                   [(63574, 89761)]
# 1362032                    [(1393, 112733), (63574, 1393)]
# 1362043                      [(1393, 3082), (63574, 1393)]
# 1362047       [(63574, 6471), (1393, 6471), (67858, 6471)]
# 1362048                                   [(63574, 67858)]
# 1362051                                    [(63574, 1393)]
# 1362063                                    [(63574, 5946)]
# 1362065                                  [(63574, 112733)]
# 1362071                                   [(63574, 67858)]
# 1362079                                   [(63574, 65712)]
# 1362107                      [(63574, 6471), (1393, 6471)]
# 1362132                                  [(63574, 111066)]
# 1362142                                  [(63574, 104362)]
# 1362171                                   [(12620, 28655)]
# 1367534  [(27104, 28701), (2273, 28701), (5063, 28701),...
# 1367604                                                 []
# 1367710                                    [(1999, 27095)]
# 1367731                                                 []
# 1367759                                                 []
# 1367835                                                 []
#
#               to_power_imds                      cc_power_rels cc_power_imds
# uid
# 204                     [1]                                 []            []
# 228                      []                    [(14758, 1786)]           [1]
# 248      [1, 1, 1, 1, 1, 1]                                 []            []
# 277                     [1]                                 []            []
# 299                      []    [(28701, 2619), (28701, 18989)]        [1, 1]
# 314                      []         [(1999, 836), (7319, 836)]        [1, 1]
# 338         [1, 1, 1, 1, 1]                                 []            []
# 2701                    [1]                                 []            []
# 2744                 [1, 1]                                 []            []
# 2745                 [1, 1]                                 []            []
# 2754                    [1]                                 []            []
# 2761                    [1]                                 []            []
# 2763                    [1]                                 []            []
# 2765                    [1]                                 []            []
# 2766                    [1]                                 []            []
# 2767                    [1]                                 []            []
# 2768                    [1]                                 []            []
# 2770                    [1]                                 []            []
# 2771                    [1]                                 []            []
# 2774                    [1]                                 []            []
# 2777                    [1]                                 []            []
# 2780                    [1]                                 []            []
# 2781                    [1]                                 []            []
# 2862                    [1]                                 []            []
# 2898                    [1]                                 []            []
# 2900                    [1]                                 []            []
# 2913                     []       [(1999, 2659), (7319, 2659)]        [1, 1]
# 2915              [1, 1, 1]                                 []            []
# 2918                    [1]                                 []            []
# 2923                    [1]                                 []            []
# ...                     ...                                ...           ...
# 1361978                 [1]                                 []            []
# 1361990                 [1]                                 []            []
# 1361994                 [1]                                 []            []
# 1362008                 [1]    [(2437, 22022), (63574, 22022)]        [1, 1]
# 1362011              [1, 1]    [(2437, 22022), (63574, 22022)]        [1, 1]
# 1362013                 [1]                                 []            []
# 1362018                 [1]                                 []            []
# 1362022                 [1]                                 []            []
# 1362026                 [1]                                 []            []
# 1362030                 [1]                   [(67858, 22022)]           [1]
# 1362031                 [1]                   [(63574, 89761)]           [1]
# 1362032              [1, 1]                    [(63574, 1393)]           [1]
# 1362043              [1, 1]                    [(63574, 1393)]           [1]
# 1362047           [1, 1, 1]                                 []            []
# 1362048                 [1]                                 []            []
# 1362051                 [1]                                 []            []
# 1362063                 [1]                    [(63574, 5946)]           [1]
# 1362065                 [1]  [(63574, 112733), (1393, 112733)]        [1, 1]
# 1362071                 [1]                                 []            []
# 1362079                 [1]                                 []            []
# 1362107              [1, 1]                                 []            []
# 1362132                 [1]                                 []            []
# 1362142                 [1]                                 []            []
# 1362171                 [1]                                 []            []
# 1367534        [1, 1, 1, 1]    [(5063, 28701), (14758, 28701)]        [1, 1]
# 1367604                  []    [(14758, 28701), (5063, 28701)]        [1, 1]
# 1367710                 [1]                                 []            []
# 1367731                  []                     [(7320, 2525)]           [1]
# 1367759                  []                    [(7320, 22475)]           [1]
# 1367835                  []                   [(5140, 114589)]           [1]
#
# [25006 rows x 22 columns]

# %%
print(data_power_only['main_text'][314])
# Out:
# All:
# A more detailed version  of CAISO's MD02 proposal was released on Wednesday.  Below I am copying a summary prepared by Andy Brown who covers these matters for IEP.
# It appears that the CAISO proposal will allow for SC's to go short or long in the R/T market (i.e., final schedules do not need to be balanced).  That's good.
# I think the most material issue at this point is how the forward capacity requirement (ACAP, akin to ICAP) will affect our trading.
# GAC
# What is CAISO proposing?
# First off, there are "target price" and "intra-zonal congestion management"
# FERC filings that are apparently almost ready for a drop at FERC.  The
# "comprehensive" package would build off that.
# In essencence, CAISO is proposing a capacity market (similar to what IEP
# proposed at the CPUC "Procurement OIR") that has an "available capacity
# obligation" (ACAP) on the load-serving entities (LSEs, aka the utilities and
# electric service providers).  This is the solution to the "all spot, all the
# time" design that was associated with the CPUC's "mandatory buy/sell"
# requirement and failure to provide forward reasonableness guidelines for the
# utilities.  The LSEs would be required to show / specify to CAISO the ACAP
# resources on a month-ahead basis equal to at least 115% of the coming
# month's peak demand.  ACAP resources can be the LSE's own generation,
# generation under contract, etc.  Failure to procure sufficient ACAP would
# lead to penalties.  Also, CAISO appears to suggest that it would be in the
# middle of arrangements between a LSE and the capacity supply as it would
# penalize the supplier for failure to be available, operate as dispatched,
# etc.  That wrinkle seems like it calls for 3 party contracts or some element
# of complexity that shouldn't necessarily be required.  Its not clear from
# the paper how costs for CAISO-dispatched ACAP resource would be allocated to
# other SCs, particularly where a LSE contracted for the capacity, but CAISO's
# running it to cover someone else's short energy schedule?
# It is not particularly clear how DWR resources fit into the mix (there seems
# to be a contradictory statement in the paper).  However, CAISO is proposing
# a two-year "transition" mechanism where CAISO would provide the ACAP
# resources (based on their stellar creditworthiness?? or DWR resources??).
# There could be tension here with the proposals at the CPUC proceeding.
# Also, it appears that an argument can be made that DWR is a LSE under the
# terms of AB 1x.
# CAISO is also moving toward a forward nodal-based congestion mechanism,
# similar to the PJM type of design.  It is based on a 3000 bus network model
# with simplified modeling of adjacent control areas.  Dispatch will be on an
# optimized basis that on resource constraints (that appears to be dynamic)
# including transmission capacity changes (increased ATC when ETC rights are
# freed up, etc.) and generation availability.  There will be some degree of
# node aggregation (in the form of demand locations and trading hubs).  It
# appears that RMR contracts could disappear under this approach, although
# that is not completely clear.
# Creation of the forward congestion approach with security based optimization
# effectively removes the need for the "balanced schedule" requirement.  Under
# the proposal, CAISO would make trades happen in realtime through the
# optimization to the extent not addressed through the forward markets. CAISO
# calls for the resurrection of a day ahead energy market (FERC has called for
# that).  CAISO says its open to that market being run outside of CAISO, but
# that the need is for a centralized day ahead energy market that could help
# shape resource needs.
# CAISO would have the ability to dispatch identified ACAP resources not
# already scheduled by the LSE.  They speak in terms of a "residual unit
# commitment" requirement ... something akin to the "long lead time" proposal
# under the "must-offer" requirement.  Their start and min load payment
# proposal would be continued, subject to loosing it for unavailability or
# participation in the market.
# Note that CAISO states they will need to mitigate bids due to "locational
# market power", particularly in relation to congestion.  I thought that
# locational market power was addressed via RMR.  This raises the "black box"
# issue if CAISO is going to say on a realtime basis that they have some
# dynamic problem and only a particular generation asset could address the
# problem so we're mitigating your bid curve based on some form of proxy
# pricing mechanism.  To some extent, in a nodal system, CAISO could argue
# that more folks have "locational market power."  We'll need to review other
# markets' treatment of this issue.
# The future of the AS markets is questioned in the paper, and there's the
# specific suggestion that the replacement reserve market is unnecessary if
# ACAP is put into place.  This is probably the largest hole in the paper,
# because there's a clear implication that something should happen and
# presumably CAISO has at least come up with some set of options on the issue
# (i.e., kill AS, have AS markets but alter products, have one AS product but
# expect low volume, etc).
# One element that seemed missing was a discussion of demand response.  In
# many respects that element has been consistently missing in the market, save
# the extraordinary conservation last summer.  There is a suggestion that the
# ACAP requirement could be addressed by demand response, but presumably that
# would need to be demand that could be dispatched by CAISO, and those
# resources are particularly limited under the current CAISO demand-side
# design.  While efforts on interruptible programs has occurred at the CPUC,
# it is not clear that the two entities are heading in the same direction.
# It was noted earlier that the ACAP proposal is similar to what IEP (and
# others) suggested at the CPUC Procurement OIR.  Based on a lone comment by a
# CPUCer during the CAISO media call yesterday, the CPUC is very far behind
# the curve on these issues, and there is absolutely no coordination on this
# issue.  Given that the same "solution" is popping up in both venues, there
# is a real need to make sure that the two pieces can fit together, while
# avoiding a bureaucratic paralysis that could happen if a formal attempt to
# "coordinate" the venues is proposed.
# ABB
# Andrew B. Brown
# Ellison, Schneider & Harris, LLP
# 2015 H Street
# Sacramento, CA  95814
# Phone: (916) 447-2166
# Fax: (916) 447-3512
# mailto:abb@eslawfirm.com
